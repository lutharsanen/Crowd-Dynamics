# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

vector_size = 10000
lst = np.random.rand(vector_size, 2)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x,y = np.array([[1,2,6,3,2,7,3,3,7,2],[1,2,6,3,2,7,3,3,7,2]])
z = [5,6,7,8,2,5,6,3,7,2]

ax.plot_wireframe(x, y, z)
